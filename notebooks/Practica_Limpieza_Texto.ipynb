# %% [markdown]
# #  Practica de limpieza de texto con pandas - Solución

# %%
import pandas as pd

# %% [markdown]
# #### Por Jose R. Zapata - https://joserzapata.github.io/
#
#
# > **Objetivo**: practicar métodos de `pandas.Series.str` para limpiar y normalizar texto en DataFrames.
# > Cada ejercicio incluye un **Enunciado** y una celda donde se ve el resultado de la solución.
#
#
#
# **Referencias:**
# - Procesamiento básico de texto (curso de NLP): https://joserzapata.github.io/courses/nlp/procesamiento-basico/
# - Documentación de `pandas.Series.str`: https://pandas.pydata.org/docs/reference/series.html#string-handling

# %% [markdown]
# ## Instalación de dependencias
#
# instala e importa las librerias que necesites para ejecutar los ejercicios, por ejemplo para instalar Jupyter usa:
#
# ```bash
# uv add jupyter
# ```

# %%
# Copie su código aca

# %%
import pandas as pd

# %% [markdown]
# ## Conjuntos de datos de juguete
# Creamos 4 DataFrames para practicar distintas tareas de limpieza: texto general, tweets, productos y personas.

# %%
## Texto general
df_texto = pd.DataFrame(
    {
        "texto": [
            "  ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita https://miweb.com  #DataScience  :)  ",
            "Pandas > numpy? 🤔  Email: persona@example.com   ",
            "Me gusta el café colombiano; es buenísimo!!! #Café #Colombia @juan",
            "Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO: A-123",
            "      TABLAS\t, \n espacios   y saltos de línea.\r\n",
            "Teléfono: (57) 300-123-45-67; Whatsapp +57 300 222 33 44",
            "Dirección: Cll 10 # 5-20; Medellín. Barrio: La América",
            "Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…",
        ]
    }
)

## Tweets
df_tweets = pd.DataFrame(
    {
        "tweet": [
            "RT @maria: Nuevo post en el blog -> http://blog.com/post?id=45 #nlp #python",
            "¡Me encanta Pandas! #datos #Python https://example.org @data_science 😊",
            "Probando cosas en Jupyter... sin link ni hashtag",
            "@juan y @ana lanzaron curso de NLP en https://cursos.ai #nlp #ml",
            "¿Pandas o Polars? debátanlo aquí 👉 https://foro.com #data",
        ]
    }
)

## Productos y precios
df_productos = pd.DataFrame(
    {
        "producto": [
            "Camisa talla M",
            "Pantalón-XL",
            "Zapato, Talla: 42",
            "Blusa s",
            "Medias 10-12",
            "Polo Talla l",
            "Vestido - 36",
            "Sombrero (talla Única)",
        ],
        "precio": [
            "$1.234,50",
            "USD 45",
            "30,00 €",
            "25.000",
            "$ 0",
            "S/. 120.90",
            "COP 9.990",
            "AR$ 2.550,00",
        ],
    }
)

## Personas, respuestas y direcciones
df_personas = pd.DataFrame(
    {
        "nombre": [
            "ana María LOPEZ",
            "Juan  perez",
            "Ñandú   Gómez",
            "Miguel (Soporte)",
            "  MÓNICA de la CRUZ  ",
            "luis-delgado",
        ],
        "categoria": ["Sí", "si", "SI ", "No", "—", None],
        "direccion": [
            "Calle 45 # 12-34, Bogotá",
            "Av. Siempre Viva 742 - Lima",
            "Cll. 10 No. 5-20 Medellín",
            "Cra 7a # 45-60, Bogotá",
            "Av. 9 #12-34  Cali",
            "Av. Insurgentes Sur 1234, CDMX",
        ],
        "id_raw": [
            "abc-0001",
            "abc 001",
            "ABC0002",
            "Abc_003",
            "abc-00004",
            "ABC-0005",
        ],
    }
)

# %% [markdown]
# ## Inspección rápida

# %% [markdown]
# - Explora los cuatro DataFrames
# - Identifica qué columnas requieren **limpieza textual** y por qué (espacios, acentos, emojis, URLs, etc.).
# - Escribe un breve comentario (como comentario en la celda) con tus observaciones.

# %%
# Copie su código aca

# %% [markdown]
# ## 1) Normaliza a minúsculas

# %% [markdown]
# En el DataFrame `df_texto`, crea una nueva columna `texto_min` que contenga el texto de la columna `texto` en minúsculas.

# %%
# Copie su código aca
df_texto["texto_min"] = df_texto["texto"].str.lower()
df_texto[["texto", "texto_min"]]
# Out:
#                                                texto  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita...
# 1   Pandas > numpy? 🤔  Email: persona@example.com
# 2  Me gusta el café colombiano; es buenísimo!!! #...
# 3  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO:...
# 4        TABLAS\t, \n espacios   y saltos de líne...
# 5  Teléfono: (57) 300-123-45-67; Whatsapp +57 300...
# 6  Dirección: Cll 10 # 5-20; Medellín. Barrio: La...
# 7         Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…
#
#                                            texto_min
# 0    ¡hola mundo!!!  esto es   un ejemplo: visita...
# 1   pandas > numpy? 🤔  email: persona@example.com
# 2  me gusta el café colombiano; es buenísimo!!! #...
# 3  oferta!!! 3x2 en jabón líquido 500ml - código:...
# 4        tablas\t, \n espacios   y saltos de líne...
# 5  teléfono: (57) 300-123-45-67; whatsapp +57 300...
# 6  dirección: cll 10 # 5-20; medellín. barrio: la...
# 7         emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…

# %% [markdown]
# ## 2) Eliminar Espacios

# %% [markdown]
# Genera  la columna `texto_espacios` eliminando espacios al inicio/fin

# %%
# Copie su código aca
df_texto["texto_espacios"] = df_texto["texto_min"].str.strip()
df_texto[["texto_espacios", "texto_min"]]
# Out:
#                                       texto_espacios  \
# 0  ¡hola mundo!!!  esto es   un ejemplo: visita h...
# 1      pandas > numpy? 🤔  email: persona@example.com
# 2  me gusta el café colombiano; es buenísimo!!! #...
# 3  oferta!!! 3x2 en jabón líquido 500ml - código:...
# 4         tablas\t, \n espacios   y saltos de línea.
# 5  teléfono: (57) 300-123-45-67; whatsapp +57 300...
# 6  dirección: cll 10 # 5-20; medellín. barrio: la...
# 7         emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…
#
#                                            texto_min
# 0    ¡hola mundo!!!  esto es   un ejemplo: visita...
# 1   pandas > numpy? 🤔  email: persona@example.com
# 2  me gusta el café colombiano; es buenísimo!!! #...
# 3  oferta!!! 3x2 en jabón líquido 500ml - código:...
# 4        tablas\t, \n espacios   y saltos de líne...
# 5  teléfono: (57) 300-123-45-67; whatsapp +57 300...
# 6  dirección: cll 10 # 5-20; medellín. barrio: la...
# 7         emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…

# %% [markdown]
# ## 3) Puntuación

# %% [markdown]
# Crea `texto_sin_punct` removiendo puntuación y símbolos, conservando letras y espacios.

# %%
# Copie su código aca
df_texto["texto_sin_punct"] = df_texto["texto_espacios"].str.replace(
    r"[^\w\s]", "", regex=True
)
df_texto["texto_sin_punct"]
# Out:
# 0    hola mundo  esto es   un ejemplo visita httpsm...
# 1              pandas  numpy   email personaexamplecom
# 2    me gusta el café colombiano es buenísimo café ...
# 3       oferta 3x2 en jabón líquido 500ml  código a123
# 4             tablas\t \n espacios   y saltos de línea
# 5     teléfono 57 3001234567 whatsapp 57 300 222 33 44
# 6     dirección cll 10  520 medellín barrio la américa
# 7                        emoji test  símbolos  y otros
# Name: texto_sin_punct, dtype: object

# %% [markdown]
# ## 4) Acentos

# %% [markdown]
# Elimina los acentos de las vocales del texto `df_texto` y grábalo en una nueva columna `texto_sin_acentos`.

# %%
# Copie su código aca
def quitar_acentos(text: str) -> str:
    MAP_VOCALES = {
        "á": "a",
        "é": "e",
        "í": "i",
        "ó": "o",
        "ú": "u",
        "ü": "u",
    }
    translate = str.maketrans(MAP_VOCALES)
    text = text.translate(translate)
    return text


df_texto["texto_sin_acentos"] = df_texto["texto_sin_punct"].apply(quitar_acentos)
df_texto["texto_sin_acentos"]
# Out:
# 0    hola mundo  esto es   un ejemplo visita httpsm...
# 1              pandas  numpy   email personaexamplecom
# 2    me gusta el cafe colombiano es buenisimo cafe ...
# 3       oferta 3x2 en jabon liquido 500ml  codigo a123
# 4             tablas\t \n espacios   y saltos de linea
# 5     telefono 57 3001234567 whatsapp 57 300 222 33 44
# 6     direccion cll 10  520 medellin barrio la america
# 7                        emoji test  simbolos  y otros
# Name: texto_sin_acentos, dtype: object

# %% [markdown]
# ## 5) Emojis

# %% [markdown]
# Crear la columna `texto_sin_emoji` quitando emojis, pictogramas y símbolos gráficos comunes.

# %%
# Copie su código aca
emoji_re = re.compile("[\U0001f300-\U0001faff\U00002700-\U000027bf]+", flags=re.UNICODE)
df_texto["texto_sin_emoji"] = df_texto["texto_espacios"].apply(
    lambda s: emoji_re.sub("", s)
)
df_texto["texto_sin_emoji"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Copie su código aca
# ----> 2 emoji_re = re.compile("[\U0001f300-\U0001faff\U00002700-\U000027bf]+", flags=re.UNICODE)
#       3 df_texto["texto_sin_emoji"] = df_texto["texto_espacios"].apply(
#       4     lambda s: emoji_re.sub("", s)
#       5 )
#       6 df_texto["texto_sin_emoji"]
#
# NameError: name 're' is not defined

# %%
import re

# %% [markdown]
# ## 6) Extrae emails y URLs

# %% [markdown]
# En `df_texto`, crea las columnas `email` y `urls` extrayendo emails y URLs del texto original.
#
# **Patrones sugeridos:**
# - Email: `[A-Za-z0-9_.+-]+@[A-Za-z0-9-]+\.[A-Za-z0-9.-]+`
# - URL: `https?://\S+`

# %%
# Copie su código aca
email_pat = r"[A-Za-z0-9_.+-]+@[A-Za-z0-9-]+\.[A-Za-z0-9.-]+"
url_pat = r"https?://\S+"
df_texto["email"] = df_texto["texto"].str.findall(email_pat)
df_texto["urls"] = df_texto["texto"].str.findall(url_pat)

df_texto[["texto", "email", "urls"]]
# Out:
#                                                texto                  email  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita...                     []
# 1   Pandas > numpy? 🤔  Email: persona@example.com     [persona@example.com]
# 2  Me gusta el café colombiano; es buenísimo!!! #...                     []
# 3  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO:...                     []
# 4        TABLAS\t, \n espacios   y saltos de líne...                     []
# 5  Teléfono: (57) 300-123-45-67; Whatsapp +57 300...                     []
# 6  Dirección: Cll 10 # 5-20; Medellín. Barrio: La...                     []
# 7         Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…                     []
#
#                   urls
# 0  [https://miweb.com]
# 1                   []
# 2                   []
# 3                   []
# 4                   []
# 5                   []
# 6                   []
# 7                   []

# %%
# Out:
#                                                                                   texto  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita https://miweb.com  #DataScience  :)
# 1                                      Pandas > numpy? 🤔  Email: persona@example.com
# 2                    Me gusta el café colombiano; es buenísimo!!! #Café #Colombia @juan
# 3                                  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO: A-123
# 4                                        TABLAS\t, \n espacios   y saltos de línea.\r\n
# 5                              Teléfono: (57) 300-123-45-67; Whatsapp +57 300 222 33 44
# 6                                Dirección: Cll 10 # 5-20; Medellín. Barrio: La América
# 7                                            Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…
#
#                    email                 urls
# 0                     []  [https://miweb.com]
# 1  [persona@example.com]                   []
# 2                     []                   []
# 3                     []                   []
# 4                     []                   []
# 5                     []                   []
# 6                     []                   []
# 7                     []                   []

# %% [markdown]
# ## 7) Hashtags, menciones y URLs en tweets

# %% [markdown]
# En `df_tweets`, crea las columnas `hashtags`, `mentions` y `urls`
# extrayendo hashtags, menciones y URLs del texto del tweet.

# %%
# Copie su código aca
pat_hash = r"#\w+"
pat_ment = r"@\w+"
pat_url = r"https?://\S+"
df_tweets["hashtags"] = df_tweets["tweet"].str.findall(pat_hash)
df_tweets["mentions"] = df_tweets["tweet"].str.findall(pat_ment)
df_tweets["urls"] = df_tweets["tweet"].str.findall(pat_url)

df_tweets
# Out:
#                                                tweet           hashtags  \
# 0  RT @maria: Nuevo post en el blog -> http://blo...    [#nlp, #python]
# 1  ¡Me encanta Pandas! #datos #Python https://exa...  [#datos, #Python]
# 2   Probando cosas en Jupyter... sin link ni hashtag                 []
# 3  @juan y @ana lanzaron curso de NLP en https://...        [#nlp, #ml]
# 4  ¿Pandas o Polars? debátanlo aquí 👉 https://for...            [#data]
#
#           mentions                          urls
# 0         [@maria]  [http://blog.com/post?id=45]
# 1  [@data_science]         [https://example.org]
# 2               []                            []
# 3    [@juan, @ana]           [https://cursos.ai]
# 4               []            [https://foro.com]

# %%
# Out:
#                                                                          tweet  \
# 0  RT @maria: Nuevo post en el blog -> http://blog.com/post?id=45 #nlp #python
# 1       ¡Me encanta Pandas! #datos #Python https://example.org @data_science 😊
# 2                             Probando cosas en Jupyter... sin link ni hashtag
# 3             @juan y @ana lanzaron curso de NLP en https://cursos.ai #nlp #ml
# 4                    ¿Pandas o Polars? debátanlo aquí 👉 https://foro.com #data
#
#             hashtags         mentions                          urls
# 0    [#nlp, #python]         [@maria]  [http://blog.com/post?id=45]
# 1  [#datos, #Python]  [@data_science]         [https://example.org]
# 2                 []               []                            []
# 3        [#nlp, #ml]    [@juan, @ana]           [https://cursos.ai]
# 4            [#data]               []            [https://foro.com]

# %% [markdown]
# ## 8) ¿Es retuit? Limpia el prefijo

# %% [markdown]
# Crea la columna `es_rt` (booleano) si el tweet comienza con `RT`. Luego genera la columna `tweet_sin_rt` quitando el prefijo `RT @usuario:` del inicio.

# %%
# Copie su código aca
df_tweets["es_rt"] = df_tweets["tweet"].str.startswith("RT ")
df_tweets["tweet_sin_rt"] = df_tweets["tweet"].str.replace(
    r"^RT\s+@\w+:\s*", "", regex=True
)

df_tweets
# Out:
#                                                tweet           hashtags  \
# 0  RT @maria: Nuevo post en el blog -> http://blo...    [#nlp, #python]
# 1  ¡Me encanta Pandas! #datos #Python https://exa...  [#datos, #Python]
# 2   Probando cosas en Jupyter... sin link ni hashtag                 []
# 3  @juan y @ana lanzaron curso de NLP en https://...        [#nlp, #ml]
# 4  ¿Pandas o Polars? debátanlo aquí 👉 https://for...            [#data]
#
#           mentions                          urls  es_rt  \
# 0         [@maria]  [http://blog.com/post?id=45]   True
# 1  [@data_science]         [https://example.org]  False
# 2               []                            []  False
# 3    [@juan, @ana]           [https://cursos.ai]  False
# 4               []            [https://foro.com]  False
#
#                                         tweet_sin_rt
# 0  Nuevo post en el blog -> http://blog.com/post?...
# 1  ¡Me encanta Pandas! #datos #Python https://exa...
# 2   Probando cosas en Jupyter... sin link ni hashtag
# 3  @juan y @ana lanzaron curso de NLP en https://...
# 4  ¿Pandas o Polars? debátanlo aquí 👉 https://for...

# %%
# Out:
#                                                                          tweet  \
# 0  RT @maria: Nuevo post en el blog -> http://blog.com/post?id=45 #nlp #python
# 1       ¡Me encanta Pandas! #datos #Python https://example.org @data_science 😊
# 2                             Probando cosas en Jupyter... sin link ni hashtag
# 3             @juan y @ana lanzaron curso de NLP en https://cursos.ai #nlp #ml
# 4                    ¿Pandas o Polars? debátanlo aquí 👉 https://foro.com #data
#
#             hashtags         mentions                          urls  es_rt  \
# 0    [#nlp, #python]         [@maria]  [http://blog.com/post?id=45]   True
# 1  [#datos, #Python]  [@data_science]         [https://example.org]  False
# 2                 []               []                            []  False
# 3        [#nlp, #ml]    [@juan, @ana]           [https://cursos.ai]  False
# 4            [#data]               []            [https://foro.com]  False
#
#                                                              tweet_sin_rt
# 0        Nuevo post en el blog -> http://blog.com/post?id=45 #nlp #python
# 1  ¡Me encanta Pandas! #datos #Python https://example.org @data_science 😊
# 2                        Probando cosas en Jupyter... sin link ni hashtag
# 3        @juan y @ana lanzaron curso de NLP en https://cursos.ai #nlp #ml
# 4               ¿Pandas o Polars? debátanlo aquí 👉 https://foro.com #data

# %% [markdown]
# ## 9) `tweet_limpio`

# %% [markdown]
# Crea `tweet_limpio` removiendo URLs, menciones y hashtags; además, elimina la puntuación sobrante, quita espacios y pasa a minúsculas.

# %%
# Copie su código aca
tmp = df_tweets["tweet_sin_rt"] if "tweet_sin_rt" in df_tweets else df_tweets["tweet"]
tmp = tmp.str.replace(r"https?://\S+", " ", regex=True)
tmp = tmp.str.replace(r"@\w+|#\w+", " ", regex=True)
tmp = tmp.str.replace(r"[^\w\sáéíóúÁÉÍÓÚñÑ]", " ", regex=True)
tmp = tmp.str.replace(r"\s+", " ", regex=True).str.strip().str.casefold()
df_tweets["tweet_limpio"] = tmp
df_tweets[["tweet", "tweet_limpio"]]
# Out:
#                                                tweet  \
# 0  RT @maria: Nuevo post en el blog -> http://blo...
# 1  ¡Me encanta Pandas! #datos #Python https://exa...
# 2   Probando cosas en Jupyter... sin link ni hashtag
# 3  @juan y @ana lanzaron curso de NLP en https://...
# 4  ¿Pandas o Polars? debátanlo aquí 👉 https://for...
#
#                                     tweet_limpio
# 0                          nuevo post en el blog
# 1                              me encanta pandas
# 2  probando cosas en jupyter sin link ni hashtag
# 3                     y lanzaron curso de nlp en
# 4                 pandas o polars debátanlo aquí

# %%
# Out:
#                                                                          tweet  \
# 0  RT @maria: Nuevo post en el blog -> http://blog.com/post?id=45 #nlp #python
# 1       ¡Me encanta Pandas! #datos #Python https://example.org @data_science 😊
# 2                             Probando cosas en Jupyter... sin link ni hashtag
# 3             @juan y @ana lanzaron curso de NLP en https://cursos.ai #nlp #ml
# 4                    ¿Pandas o Polars? debátanlo aquí 👉 https://foro.com #data
#
#                                     tweet_limpio
# 0                          nuevo post en el blog
# 1                              me encanta pandas
# 2  probando cosas en jupyter sin link ni hashtag
# 3                     y lanzaron curso de nlp en
# 4                 pandas o polars debátanlo aquí

# %% [markdown]
# ## 10) Talla en `df_productos`

# %% [markdown]
# Extrae y estandariza la talla:
# - Letras: `XS, S, M, L, XL, XXL`, o `TU` (talla única).
# - Números: captura como `talla_num`.
# Crea la columna`talla_std` (letras) y `talla_num` (numérica).

# %%
# Copie su código aca
pat_letra = r"(?i)\b(xs|s|m|l|xl|xxl|única|unica|u)\b"
pat_num = r"(\d+(?:\.\d+)?)"


def extraer_talla(row):
    txt = str(row["producto"])
    m1 = re.search(pat_letra, txt)
    m2 = re.search(pat_num, txt)
    talla_std = None
    talla_num = None
    if m1:
        val = m1.group(1).lower()
        talla_std = "TU" if val in {"única", "unica", "u"} else val.upper()
    if m2:
        talla_num = float(m2.group(1)) if m2.group(1) is not None else None
    return pd.Series({"talla_std": talla_std, "talla_num": talla_num})


df_productos[["talla_std", "talla_num"]] = df_productos.apply(extraer_talla, axis=1)
df_productos
# Out:
#                  producto        precio talla_std  talla_num
# 0          Camisa talla M     $1.234,50         M        NaN
# 1             Pantalón-XL        USD 45        XL        NaN
# 2       Zapato, Talla: 42       30,00 €       NaN       42.0
# 3                 Blusa s        25.000         S        NaN
# 4            Medias 10-12           $ 0       NaN       10.0
# 5            Polo Talla l    S/. 120.90         L        NaN
# 6            Vestido - 36     COP 9.990       NaN       36.0
# 7  Sombrero (talla Única)  AR$ 2.550,00        TU        NaN

# %%
# Out:
#                  producto        precio talla_std  talla_num
# 0          Camisa talla M     $1.234,50         M        NaN
# 1             Pantalón-XL        USD 45        XL        NaN
# 2       Zapato, Talla: 42       30,00 €       NaN       42.0
# 3                 Blusa s        25.000         S        NaN
# 4            Medias 10-12           $ 0       NaN       10.0
# 5            Polo Talla l    S/. 120.90         L        NaN
# 6            Vestido - 36     COP 9.990       NaN       36.0
# 7  Sombrero (talla Única)  AR$ 2.550,00        TU        NaN

# %% [markdown]
# ## 11) Extraer de precios

# %% [markdown]
# Convierte la columna `precio` a numérico (`precio_num`) independiente del formato (`$1.234,50`, `USD 45`, `30,00 €`, `COP 9.990`, etc.).

# %%
# Copie su código aca
def parse_precio(s):
    if pd.isna(s):
        return np.nan
    # 1. Quitar todo lo que no sea un dígito, una coma o un punto
    s = str(s).replace("\xa0", " ").strip()
    s2 = re.sub(r"[^0-9,.]", "", s)

    # 2. Si hay coma y punto, asumir que el punto es separador de miles y la coma de decimales
    if "," in s2 and "." in s2:
        # Si la coma está después del punto, es decimal
        if s2.rfind(",") > s2.rfind("."):
            s2 = s2.replace(".", "").replace(",", ".")
        # Si el punto está después de la coma, es decimal
        else:
            s2 = s2.replace(",", "")
    # 3. Si solo hay coma, asumirla como decimal
    elif "," in s2:
        s2 = s2.replace(",", ".")

    # 4. Si hay más de un punto, son separadores de miles
    if s2.count(".") > 1:
        # Quitar todos los puntos menos el último
        s2 = s2.replace(".", "", s2.count(".") - 1)

    try:
        return float(s2)
    except (ValueError, TypeError):
        return np.nan


df_productos["precio_num"] = df_productos["precio"].apply(parse_precio)
df_productos
# Out:
#                  producto        precio talla_std  talla_num  precio_num
# 0          Camisa talla M     $1.234,50         M        NaN     1234.50
# 1             Pantalón-XL        USD 45        XL        NaN       45.00
# 2       Zapato, Talla: 42       30,00 €       NaN       42.0       30.00
# 3                 Blusa s        25.000         S        NaN       25.00
# 4            Medias 10-12           $ 0       NaN       10.0        0.00
# 5            Polo Talla l    S/. 120.90         L        NaN      120.90
# 6            Vestido - 36     COP 9.990       NaN       36.0        9.99
# 7  Sombrero (talla Única)  AR$ 2.550,00        TU        NaN     2550.00

# %%
import numpy as np

# %% [markdown]
# ## 12) Filtrado por texto

# %% [markdown]
# Filtra el DataFrame `df_productos` para mostrar solo filas cuyo `producto` contenga **camisa** o **pantalón**, ignorando acentos y mayúsculas/minúsculas.

# %%
# Copie su código aca
mask = (
    df_productos["producto"]
    .str.lower()
    .apply(quitar_acentos)
    .str.contains("camisa|pantalon")
)
df_productos[mask]
# Out:
#          producto     precio talla_std  talla_num  precio_num
# 0  Camisa talla M  $1.234,50         M        NaN      1234.5
# 1     Pantalón-XL     USD 45        XL        NaN        45.0

# %%
# Out:
#          producto     precio talla_std  talla_num  precio_num
# 0  Camisa talla M  $1.234,50         M        NaN      1234.5
# 1     Pantalón-XL     USD 45        XL        NaN        45.0

# %% [markdown]
# ## 13) Limpieza de nombres propios

# %% [markdown]
# En el DataFrame `df_personas`, crea `nombre_limpio` en `df_personas`:
# - Quita paréntesis y su contenido.
# - Reemplaza guiones por espacio y elimina espacios extra.
# - Aplica *title case* y conserva conectores (`de`, `del`, `la`, `y`) en minúscula.

# %%
# Copie su código aca
def limpiar_nombre(s):
    s = re.sub(r"\([^)]*\)", " ", str(s))
    s = s.replace("-", " ")
    s = re.sub(r"\s+", " ", s).strip()
    s = s.title()
    for w in [" De ", " Del ", " La ", " Y "]:
        s = s.replace(w, w.lower())
    return s


df_personas["nombre_limpio"] = df_personas["nombre"].apply(limpiar_nombre)
df_personas["nombre_limpio"]
# Out:
# 0      Ana María Lopez
# 1           Juan Perez
# 2          Ñandú Gómez
# 3               Miguel
# 4    Mónica de la Cruz
# 5         Luis Delgado
# Name: nombre_limpio, dtype: object

# %%
# Out:
# 0      Ana María Lopez
# 1           Juan Perez
# 2          Ñandú Gómez
# 3               Miguel
# 4    Mónica de la Cruz
# 5         Luis Delgado
# Name: nombre_limpio, dtype: object

# %% [markdown]
# ## 14) Normaliza respuestas categóricas

# %% [markdown]
# En el DataFrame `df_personas`, convierte `categoria` en booleano `categoria_bool` donde cualquier variante de **sí** (con/ sin tilde) sea `True`; el resto `False`.

# %%
# Copie su código aca
def a_bool_si(s):
    if s is None:
        return False
    val = str(s).strip().casefold()
    return val in {"si", "sí", "si.", "sí."}


df_personas["categoria_bool"] = df_personas["categoria"].apply(a_bool_si)
df_personas
# Out:
#                   nombre categoria                       direccion     id_raw  \
# 0        ana María LOPEZ        Sí        Calle 45 # 12-34, Bogotá   abc-0001
# 1            Juan  perez        si     Av. Siempre Viva 742 - Lima    abc 001
# 2          Ñandú   Gómez       SI        Cll. 10 No. 5-20 Medellín    ABC0002
# 3       Miguel (Soporte)        No          Cra 7a # 45-60, Bogotá    Abc_003
# 4    MÓNICA de la CRUZ           —              Av. 9 #12-34  Cali  abc-00004
# 5           luis-delgado      None  Av. Insurgentes Sur 1234, CDMX   ABC-0005
#
#        nombre_limpio  categoria_bool
# 0    Ana María Lopez            True
# 1         Juan Perez            True
# 2        Ñandú Gómez            True
# 3             Miguel           False
# 4  Mónica de la Cruz           False
# 5       Luis Delgado           False

# %%
# Out:
#                   nombre categoria                       direccion     id_raw  \
# 0        ana María LOPEZ        Sí        Calle 45 # 12-34, Bogotá   abc-0001
# 1            Juan  perez        si     Av. Siempre Viva 742 - Lima    abc 001
# 2          Ñandú   Gómez       SI        Cll. 10 No. 5-20 Medellín    ABC0002
# 3       Miguel (Soporte)        No          Cra 7a # 45-60, Bogotá    Abc_003
# 4    MÓNICA de la CRUZ           —              Av. 9 #12-34  Cali  abc-00004
# 5           luis-delgado      None  Av. Insurgentes Sur 1234, CDMX   ABC-0005
#
#        nombre_limpio  categoria_bool
# 0    Ana María Lopez            True
# 1         Juan Perez            True
# 2        Ñandú Gómez            True
# 3             Miguel           False
# 4  Mónica de la Cruz           False
# 5       Luis Delgado           False

# %% [markdown]
# ## 15) Ciudad desde la dirección

# %% [markdown]
# En el DataFrame `df_personas`, Extrae la **ciudad** en una columna `ciudad`

# %%
# Copie su código aca
def extraer_ciudad(s):
    s = str(s)
    m = re.search(r",\s*([^,]+)$", s)
    if m:
        return m.group(1).strip()
    return s.strip().split()[-1]


df_personas["ciudad"] = df_personas["direccion"].apply(extraer_ciudad)
df_personas
# Out:
#                   nombre categoria                       direccion     id_raw  \
# 0        ana María LOPEZ        Sí        Calle 45 # 12-34, Bogotá   abc-0001
# 1            Juan  perez        si     Av. Siempre Viva 742 - Lima    abc 001
# 2          Ñandú   Gómez       SI        Cll. 10 No. 5-20 Medellín    ABC0002
# 3       Miguel (Soporte)        No          Cra 7a # 45-60, Bogotá    Abc_003
# 4    MÓNICA de la CRUZ           —              Av. 9 #12-34  Cali  abc-00004
# 5           luis-delgado      None  Av. Insurgentes Sur 1234, CDMX   ABC-0005
#
#        nombre_limpio  categoria_bool    ciudad
# 0    Ana María Lopez            True    Bogotá
# 1         Juan Perez            True      Lima
# 2        Ñandú Gómez            True  Medellín
# 3             Miguel           False    Bogotá
# 4  Mónica de la Cruz           False      Cali
# 5       Luis Delgado           False      CDMX

# %%
# Out:
#                   nombre categoria                       direccion     id_raw  \
# 0        ana María LOPEZ        Sí        Calle 45 # 12-34, Bogotá   abc-0001
# 1            Juan  perez        si     Av. Siempre Viva 742 - Lima    abc 001
# 2          Ñandú   Gómez       SI        Cll. 10 No. 5-20 Medellín    ABC0002
# 3       Miguel (Soporte)        No          Cra 7a # 45-60, Bogotá    Abc_003
# 4    MÓNICA de la CRUZ           —              Av. 9 #12-34  Cali  abc-00004
# 5           luis-delgado      None  Av. Insurgentes Sur 1234, CDMX   ABC-0005
#
#        nombre_limpio  categoria_bool    ciudad
# 0    Ana María Lopez            True    Bogotá
# 1         Juan Perez            True      Lima
# 2        Ñandú Gómez            True  Medellín
# 3             Miguel           False    Bogotá
# 4  Mónica de la Cruz           False      Cali
# 5       Luis Delgado           False      CDMX

# %% [markdown]
# ## 16) Normaliza y valida IDs

# %% [markdown]
# En el DataFrame `df_personas`, a partir de `id_raw`, crea la columna `id_norm` con formato `ABC-0001` (tres letras + guion + 4 dígitos) y `id_valido` (True/False).

# %%
# Copie su código aca
def normalizar_id(s):
    m = re.search(r"([A-Za-z]{3})\s*[-_ ]?\s*(\d+)", str(s))
    if not m:
        return None
    pref = m.group(1).upper()
    num = int(m.group(2))
    return f"{pref}-{num:04d}"


df_personas["id_norm"] = df_personas["id_raw"].apply(normalizar_id)
df_personas["id_valido"] = df_personas["id_norm"].str.match(r"^[A-Z]{3}-\d{4}$")
df_personas[["id_raw", "id_norm", "id_valido"]]
# Out:
#       id_raw   id_norm  id_valido
# 0   abc-0001  ABC-0001       True
# 1    abc 001  ABC-0001       True
# 2    ABC0002  ABC-0002       True
# 3    Abc_003  ABC-0003       True
# 4  abc-00004  ABC-0004       True
# 5   ABC-0005  ABC-0005       True

# %%
# Out:
#       id_raw   id_norm  id_valido
# 0   abc-0001  ABC-0001       True
# 1    abc 001  ABC-0001       True
# 2    ABC0002  ABC-0002       True
# 3    Abc_003  ABC-0003       True
# 4  abc-00004  ABC-0004       True
# 5   ABC-0005  ABC-0005       True

# %% [markdown]
# ## 17) Mini *pipeline* de limpieza general

# %% [markdown]
# Escribe una función `limpia_basica(s)` que: ponga el texto en minuscula, quite acentos, URLs, menciones y hashtags, puntuación, dígitos y colapse espacios. Aplícala a `df_texto['texto']` y guarda en `texto_limpio_final`.

# %%
# Copie su código aca
def limpia_basica(s: str) -> str:
    """Limpieza básica de texto.

    Convierte a minúsculas, quita acentos, URLs, menciones y hashtags,
    puntuación, dígitos y quita espacios.

    Arguments:
        s (str): Texto a limpiar.

    Returns:
        str: Texto limpio.

        Ejemplo:
        >>> limpia_basica('  ¡Hola Mundo!!! Visita https://miweb.com  #DataScience  :)  ')
        'hola mundo visita'


    """

    if s is None:
        return s
    s = str(s).lower()
    MAP_VOCALES = {
        "á": "a",
        "é": "e",
        "í": "i",
        "ó": "o",
        "ú": "u",
        "ü": "u",
    }
    translate = str.maketrans(MAP_VOCALES)
    s = s.translate(translate)
    s = re.sub(r"https?://\S+", " ", s)
    s = re.sub(r"[@#]\w+", " ", s)
    s = re.sub(r"[^a-z\sñ]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s


df_texto["texto_limpio_final"] = df_texto["texto"].apply(limpia_basica)
df_texto[["texto", "texto_limpio_final"]]
# Out:
#                                                texto  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita...
# 1   Pandas > numpy? 🤔  Email: persona@example.com
# 2  Me gusta el café colombiano; es buenísimo!!! #...
# 3  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO:...
# 4        TABLAS\t, \n espacios   y saltos de líne...
# 5  Teléfono: (57) 300-123-45-67; Whatsapp +57 300...
# 6  Dirección: Cll 10 # 5-20; Medellín. Barrio: La...
# 7         Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…
#
#                          texto_limpio_final
# 0      hola mundo esto es un ejemplo visita
# 1            pandas numpy email persona com
# 2  me gusta el cafe colombiano es buenisimo
# 3     oferta x en jabon liquido ml codigo a
# 4         tablas espacios y saltos de linea
# 5                         telefono whatsapp
# 6  direccion cll medellin barrio la america
# 7               emoji test simbolos y otros

# %%
# Out:
#                                                                                   texto  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita https://miweb.com  #DataScience  :)
# 1                                      Pandas > numpy? 🤔  Email: persona@example.com
# 2                    Me gusta el café colombiano; es buenísimo!!! #Café #Colombia @juan
# 3                                  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO: A-123
# 4                                        TABLAS\t, \n espacios   y saltos de línea.\r\n
# 5                              Teléfono: (57) 300-123-45-67; Whatsapp +57 300 222 33 44
# 6                                Dirección: Cll 10 # 5-20; Medellín. Barrio: La América
# 7                                            Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…
#
#                          texto_limpio_final
# 0      hola mundo esto es un ejemplo visita
# 1            pandas numpy email persona com
# 2  me gusta el cafe colombiano es buenisimo
# 3     oferta x en jabon liquido ml codigo a
# 4         tablas espacios y saltos de linea
# 5                         telefono whatsapp
# 6  direccion cll medellin barrio la america
# 7               emoji test simbolos y otros

# %% [markdown]
# ## 18)¿Qué tanto cambió el texto?

# %% [markdown]
# En el dataframe `df_texto`,
#
# Cual es la diferencia entre la longitud original (`len_raw`) y la longitud tras la limpieza (`len_clean`)?

# %%
# Copie su código aca
df_texto["len_raw"] = df_texto["texto"].str.len()
df_texto["len_clean"] = df_texto["texto_limpio_final"].str.len()
df_texto[["texto", "texto_limpio_final", "len_raw", "len_clean"]]
# Out:
#                                                texto  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita...
# 1   Pandas > numpy? 🤔  Email: persona@example.com
# 2  Me gusta el café colombiano; es buenísimo!!! #...
# 3  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO:...
# 4        TABLAS\t, \n espacios   y saltos de líne...
# 5  Teléfono: (57) 300-123-45-67; Whatsapp +57 300...
# 6  Dirección: Cll 10 # 5-20; Medellín. Barrio: La...
# 7         Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…
#
#                          texto_limpio_final  len_raw  len_clean
# 0      hola mundo esto es un ejemplo visita       84         36
# 1            pandas numpy email persona com       48         30
# 2  me gusta el cafe colombiano es buenisimo       66         40
# 3     oferta x en jabon liquido ml codigo a       52         37
# 4         tablas espacios y saltos de linea       48         33
# 5                         telefono whatsapp       56         17
# 6  direccion cll medellin barrio la america       54         40
# 7               emoji test simbolos y otros       42         27

# %%
# Out:
#                                                                                   texto  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita https://miweb.com  #DataScience  :)
# 1                                      Pandas > numpy? 🤔  Email: persona@example.com
# 2                    Me gusta el café colombiano; es buenísimo!!! #Café #Colombia @juan
# 3                                  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO: A-123
# 4                                        TABLAS\t, \n espacios   y saltos de línea.\r\n
# 5                              Teléfono: (57) 300-123-45-67; Whatsapp +57 300 222 33 44
# 6                                Dirección: Cll 10 # 5-20; Medellín. Barrio: La América
# 7                                            Emoji test: 😀🙌🏽🏳️‍🌈, símbolos ©®™ y otros…
#
#                          texto_limpio_final  len_raw  len_clean
# 0      hola mundo esto es un ejemplo visita       84         36
# 1            pandas numpy email persona com       48         30
# 2  me gusta el cafe colombiano es buenisimo       66         40
# 3     oferta x en jabon liquido ml codigo a       52         37
# 4         tablas espacios y saltos de linea       48         33
# 5                         telefono whatsapp       56         17
# 6  direccion cll medellin barrio la america       54         40
# 7               emoji test simbolos y otros       42         27

# %% [markdown]
# ### Guardar de resultados
#
# Guarda el dataframe df_texto en parquet con `df_texto.to_parquet('archivo.parquet', index=False)`.

# %%
# !sudo chown -R $(whoami) .
# Out:
# chown: changing ownership of './proc/fb': Permission denied
# chown: changing ownership of './proc/fs/cifs/Stats': Read-only file system
# chown: changing ownership of './proc/fs/cifs/cifsFYI': Read-only file system
# chown: changing ownership of './proc/fs/cifs/dfscache': Read-only file system
# chown: changing ownership of './proc/fs/cifs/traceSMB': Read-only file system
# chown: changing ownership of './proc/fs/cifs/DebugData': Read-only file system
# chown: changing ownership of './proc/fs/cifs/open_files': Read-only file system
# chown: changing ownership of './proc/fs/cifs/mount_params': Read-only file system
# chown: changing ownership of './proc/fs/cifs/SecurityFlags': Read-only file system
# chown: changing ownership of './proc/fs/cifs/LookupCacheEnabled': Read-only file system
# chown: changing ownership of './proc/fs/cifs/LinuxExtensionsEnabled': Read-only file system
# chown: changing ownership of './proc/fs/cifs': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sda1/fc_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sda1/options': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sda1/mb_stats': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sda1/mb_groups': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sda1/es_shrinker_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sda1/mb_structs_summary': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sda1': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdb1/fc_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdb1/options': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdb1/mb_stats': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdb1/mb_groups': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdb1/es_shrinker_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdb1/mb_structs_summary': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdb1': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdc1/fc_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdc1/options': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdc1/mb_stats': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdc1/mb_groups': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdc1/es_shrinker_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdc1/mb_structs_summary': Read-only file system
# chown: changing ownership of './proc/fs/ext4/sdc1': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop3/fc_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop3/options': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop3/mb_stats': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop3/mb_groups': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop3/es_shrinker_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop3/mb_structs_summary': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop3': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop4/fc_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop4/options': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop4/mb_stats': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop4/mb_groups': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop4/es_shrinker_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop4/mb_structs_summary': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop4': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop5/fc_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop5/options': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop5/mb_stats': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop5/mb_groups': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop5/es_shrinker_info': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop5/mb_structs_summary': Read-only file system
# chown: changing ownership of './proc/fs/ext4/loop5': Read-only file system
# chown: changing ownership of './proc/fs/ext4': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/sda1-8/info': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/sda1-8': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/sdb1-8/info': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/sdb1-8': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/sdc1-8/info': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/sdc1-8': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/loop3-8/info': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/loop3-8': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/loop4-8/info': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/loop4-8': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/loop5-8/info': Read-only file system
# chown: changing ownership of './proc/fs/jbd2/loop5-8': Read-only file system
# chown: changing ownership of './proc/fs/jbd2': Read-only file system
# chown: changing ownership of './proc/fs/nfsd': Read-only file system
# chown: changing ownership of './proc/fs/netfs/stats': Read-only file system
# chown: changing ownership of './proc/fs/netfs/caches': Read-only file system
# chown: changing ownership of './proc/fs/netfs/cookies': Read-only file system
# chown: changing ownership of './proc/fs/netfs/volumes': Read-only file system
# chown: changing ownership of './proc/fs/netfs/requests': Read-only file system
# chown: changing ownership of './proc/fs/netfs': Read-only file system
# chown: changing ownership of './proc/fs/fscache': Read-only file system
# chown: changing ownership of './proc/fs': Read-only file system
# chown: changing ownership of './proc/bus/pci/00/00.0': Read-only file system
# chown: changing ownership of './proc/bus/pci/00/07.0': Read-only file system
# chown: changing ownership of './proc/bus/pci/00/07.1': Read-only file system
# chown: changing ownership of './proc/bus/pci/00/07.3': Read-only file system
# chown: changing ownership of './proc/bus/pci/00/08.0': Read-only file system
# chown: changing ownership of './proc/bus/pci/00': Read-only file system
# chown: changing ownership of './proc/bus/pci/devices': Read-only file system
# chown: changing ownership of './proc/bus/pci': Read-only file system
# chown: changing ownership of './proc/bus/input/devices': Read-only file system
# chown: changing ownership of './proc/bus/input/handlers': Read-only file system
# chown: changing ownership of './proc/bus/input': Read-only file system
# chown: changing ownership of './proc/bus': Read-only file system
# chown: changing ownership of './proc/dma': Permission denied
# chown: changing ownership of './proc/irq/0/node': Read-only file system
# chown: changing ownership of './proc/irq/0/spurious': Read-only file system
# chown: changing ownership of './proc/irq/0/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/0/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/0/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/0/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/0/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/0': Read-only file system
# chown: changing ownership of './proc/irq/1/node': Read-only file system
# chown: changing ownership of './proc/irq/1/i8042': Read-only file system
# chown: changing ownership of './proc/irq/1/spurious': Read-only file system
# chown: changing ownership of './proc/irq/1/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/1/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/1/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/1/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/1/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/1': Read-only file system
# chown: changing ownership of './proc/irq/2/node': Read-only file system
# chown: changing ownership of './proc/irq/2/spurious': Read-only file system
# chown: changing ownership of './proc/irq/2/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/2/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/2/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/2/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/2/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/2': Read-only file system
# chown: changing ownership of './proc/irq/3/node': Read-only file system
# chown: changing ownership of './proc/irq/3/spurious': Read-only file system
# chown: changing ownership of './proc/irq/3/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/3/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/3/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/3/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/3/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/3': Read-only file system
# chown: changing ownership of './proc/irq/4/node': Read-only file system
# chown: changing ownership of './proc/irq/4/ttyS0': Read-only file system
# chown: changing ownership of './proc/irq/4/spurious': Read-only file system
# chown: changing ownership of './proc/irq/4/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/4/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/4/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/4/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/4/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/4': Read-only file system
# chown: changing ownership of './proc/irq/5/node': Read-only file system
# chown: changing ownership of './proc/irq/5/spurious': Read-only file system
# chown: changing ownership of './proc/irq/5/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/5/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/5/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/5/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/5/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/5': Read-only file system
# chown: changing ownership of './proc/irq/6/node': Read-only file system
# chown: changing ownership of './proc/irq/6/spurious': Read-only file system
# chown: changing ownership of './proc/irq/6/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/6/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/6/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/6/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/6/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/6': Read-only file system
# chown: changing ownership of './proc/irq/7/node': Read-only file system
# chown: changing ownership of './proc/irq/7/spurious': Read-only file system
# chown: changing ownership of './proc/irq/7/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/7/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/7/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/7/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/7/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/7': Read-only file system
# chown: changing ownership of './proc/irq/8/node': Read-only file system
# chown: changing ownership of './proc/irq/8/rtc0': Read-only file system
# chown: changing ownership of './proc/irq/8/spurious': Read-only file system
# chown: changing ownership of './proc/irq/8/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/8/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/8/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/8/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/8/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/8': Read-only file system
# chown: changing ownership of './proc/irq/9/acpi': Read-only file system
# chown: changing ownership of './proc/irq/9/node': Read-only file system
# chown: changing ownership of './proc/irq/9/spurious': Read-only file system
# chown: changing ownership of './proc/irq/9/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/9/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/9/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/9/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/9/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/9': Read-only file system
# chown: changing ownership of './proc/irq/10/node': Read-only file system
# chown: changing ownership of './proc/irq/10/spurious': Read-only file system
# chown: changing ownership of './proc/irq/10/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/10/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/10/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/10/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/10/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/10': Read-only file system
# chown: changing ownership of './proc/irq/11/node': Read-only file system
# chown: changing ownership of './proc/irq/11/spurious': Read-only file system
# chown: changing ownership of './proc/irq/11/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/11/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/11/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/11/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/11/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/11': Read-only file system
# chown: changing ownership of './proc/irq/12/node': Read-only file system
# chown: changing ownership of './proc/irq/12/i8042': Read-only file system
# chown: changing ownership of './proc/irq/12/spurious': Read-only file system
# chown: changing ownership of './proc/irq/12/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/12/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/12/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/12/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/12/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/12': Read-only file system
# chown: changing ownership of './proc/irq/13/node': Read-only file system
# chown: changing ownership of './proc/irq/13/spurious': Read-only file system
# chown: changing ownership of './proc/irq/13/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/13/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/13/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/13/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/13/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/13': Read-only file system
# chown: changing ownership of './proc/irq/14/node': Read-only file system
# chown: changing ownership of './proc/irq/14/ata_piix': Read-only file system
# chown: changing ownership of './proc/irq/14/spurious': Read-only file system
# chown: changing ownership of './proc/irq/14/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/14/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/14/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/14/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/14/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/14': Read-only file system
# chown: changing ownership of './proc/irq/15/node': Read-only file system
# chown: changing ownership of './proc/irq/15/ata_piix': Read-only file system
# chown: changing ownership of './proc/irq/15/spurious': Read-only file system
# chown: changing ownership of './proc/irq/15/smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq/15/affinity_hint': Read-only file system
# chown: changing ownership of './proc/irq/15/smp_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/15/effective_affinity': Read-only file system
# chown: changing ownership of './proc/irq/15/effective_affinity_list': Read-only file system
# chown: changing ownership of './proc/irq/15': Read-only file system
# chown: changing ownership of './proc/irq/default_smp_affinity': Read-only file system
# chown: changing ownership of './proc/irq': Read-only file system
# chown: changing ownership of './proc/net': Permission denied
# chown: changing ownership of './proc/sys/abi/vsyscall32': Read-only file system
# chown: changing ownership of './proc/sys/abi': Read-only file system
# chown: changing ownership of './proc/sys/debug/exception-trace': Read-only file system
# chown: changing ownership of './proc/sys/debug/kprobes-optimization': Read-only file system
# chown: changing ownership of './proc/sys/debug': Read-only file system
# chown: changing ownership of './proc/sys/dev/cdrom/autoclose': Read-only file system
# chown: changing ownership of './proc/sys/dev/cdrom/autoeject': Read-only file system
# chown: changing ownership of './proc/sys/dev/cdrom/check_media': Read-only file system
# chown: changing ownership of './proc/sys/dev/cdrom/debug': Read-only file system
# chown: changing ownership of './proc/sys/dev/cdrom/info': Read-only file system
# chown: changing ownership of './proc/sys/dev/cdrom/lock': Read-only file system
# chown: changing ownership of './proc/sys/dev/cdrom': Read-only file system
# chown: changing ownership of './proc/sys/dev/hpet/max-user-freq': Read-only file system
# chown: changing ownership of './proc/sys/dev/hpet': Read-only file system
# chown: changing ownership of './proc/sys/dev/raid/speed_limit_max': Read-only file system
# chown: changing ownership of './proc/sys/dev/raid/speed_limit_min': Read-only file system
# chown: changing ownership of './proc/sys/dev/raid': Read-only file system
# chown: changing ownership of './proc/sys/dev/scsi/logging_level': Read-only file system
# chown: changing ownership of './proc/sys/dev/scsi': Read-only file system
# chown: changing ownership of './proc/sys/dev/tty/ldisc_autoload': Read-only file system
# chown: changing ownership of './proc/sys/dev/tty/legacy_tiocsti': Read-only file system
# chown: changing ownership of './proc/sys/dev/tty': Read-only file system
# chown: changing ownership of './proc/sys/dev': Read-only file system
# chown: changing ownership of './proc/sys/fs/aio-max-nr': Read-only file system
# chown: changing ownership of './proc/sys/fs/aio-nr': Read-only file system
# chown: changing ownership of './proc/sys/fs/binfmt_misc': Read-only file system
# chown: changing ownership of './proc/sys/fs/dentry-state': Read-only file system
# chown: changing ownership of './proc/sys/fs/dir-notify-enable': Read-only file system
# chown: changing ownership of './proc/sys/fs/epoll/max_user_watches': Read-only file system
# chown: changing ownership of './proc/sys/fs/epoll': Read-only file system
# chown: changing ownership of './proc/sys/fs/fanotify/max_queued_events': Read-only file system
# chown: changing ownership of './proc/sys/fs/fanotify/max_user_groups': Read-only file system
# chown: changing ownership of './proc/sys/fs/fanotify/max_user_marks': Read-only file system
# chown: changing ownership of './proc/sys/fs/fanotify': Read-only file system
# chown: changing ownership of './proc/sys/fs/file-max': Read-only file system
# chown: changing ownership of './proc/sys/fs/file-nr': Read-only file system
# chown: changing ownership of './proc/sys/fs/inode-nr': Read-only file system
# chown: changing ownership of './proc/sys/fs/inode-state': Read-only file system
# chown: changing ownership of './proc/sys/fs/inotify/max_queued_events': Read-only file system
# chown: changing ownership of './proc/sys/fs/inotify/max_user_instances': Read-only file system
# chown: changing ownership of './proc/sys/fs/inotify/max_user_watches': Read-only file system
# chown: changing ownership of './proc/sys/fs/inotify': Read-only file system
# chown: changing ownership of './proc/sys/fs/lease-break-time': Read-only file system
# chown: changing ownership of './proc/sys/fs/leases-enable': Read-only file system
# chown: changing ownership of './proc/sys/fs/mount-max': Read-only file system
# chown: changing ownership of './proc/sys/fs/mqueue/msg_default': Read-only file system
# chown: changing ownership of './proc/sys/fs/mqueue/msg_max': Read-only file system
# chown: changing ownership of './proc/sys/fs/mqueue/msgsize_default': Read-only file system
# chown: changing ownership of './proc/sys/fs/mqueue/msgsize_max': Read-only file system
# chown: changing ownership of './proc/sys/fs/mqueue/queues_max': Read-only file system
# chown: changing ownership of './proc/sys/fs/mqueue': Read-only file system
# chown: changing ownership of './proc/sys/fs/nr_open': Read-only file system
# chown: changing ownership of './proc/sys/fs/overflowgid': Read-only file system
# chown: changing ownership of './proc/sys/fs/overflowuid': Read-only file system
# chown: changing ownership of './proc/sys/fs/pipe-max-size': Read-only file system
# chown: changing ownership of './proc/sys/fs/pipe-user-pages-hard': Read-only file system
# chown: changing ownership of './proc/sys/fs/pipe-user-pages-soft': Read-only file system
# chown: changing ownership of './proc/sys/fs/protected_fifos': Read-only file system
# chown: changing ownership of './proc/sys/fs/protected_hardlinks': Read-only file system
# chown: changing ownership of './proc/sys/fs/protected_regular': Read-only file system
# chown: changing ownership of './proc/sys/fs/protected_symlinks': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/allocated_dquots': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/cache_hits': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/drops': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/free_dquots': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/lookups': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/reads': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/syncs': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota/writes': Read-only file system
# chown: changing ownership of './proc/sys/fs/quota': Read-only file system
# chown: changing ownership of './proc/sys/fs/suid_dumpable': Read-only file system
# chown: changing ownership of './proc/sys/fs/verity/require_signatures': Read-only file system
# chown: changing ownership of './proc/sys/fs/verity': Read-only file system
# chown: changing ownership of './proc/sys/fs': Read-only file system
# chown: changing ownership of './proc/sys/kernel/acct': Read-only file system
# chown: changing ownership of './proc/sys/kernel/acpi_video_flags': Read-only file system
# chown: changing ownership of './proc/sys/kernel/apparmor_display_secid_mode': Read-only file system
# chown: changing ownership of './proc/sys/kernel/apparmor_restrict_unprivileged_io_uring': Read-only file system
# chown: changing ownership of './proc/sys/kernel/apparmor_restrict_unprivileged_unconfined': Read-only file system
# chown: changing ownership of './proc/sys/kernel/apparmor_restrict_unprivileged_userns': Read-only file system
# chown: changing ownership of './proc/sys/kernel/apparmor_restrict_unprivileged_userns_complain': Read-only file system
# chown: changing ownership of './proc/sys/kernel/apparmor_restrict_unprivileged_userns_force': Read-only file system
# chown: changing ownership of './proc/sys/kernel/arch': Read-only file system
# chown: changing ownership of './proc/sys/kernel/auto_msgmni': Read-only file system
# chown: changing ownership of './proc/sys/kernel/bootloader_type': Read-only file system
# chown: changing ownership of './proc/sys/kernel/bootloader_version': Read-only file system
# chown: changing ownership of './proc/sys/kernel/bpf_stats_enabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/cad_pid': Read-only file system
# chown: changing ownership of './proc/sys/kernel/cap_last_cap': Read-only file system
# chown: changing ownership of './proc/sys/kernel/core_pattern': Read-only file system
# chown: changing ownership of './proc/sys/kernel/core_pipe_limit': Read-only file system
# chown: changing ownership of './proc/sys/kernel/core_uses_pid': Read-only file system
# chown: changing ownership of './proc/sys/kernel/ctrl-alt-del': Read-only file system
# chown: changing ownership of './proc/sys/kernel/dmesg_restrict': Read-only file system
# chown: changing ownership of './proc/sys/kernel/domainname': Read-only file system
# chown: changing ownership of './proc/sys/kernel/firmware_config/force_sysfs_fallback': Read-only file system
# chown: changing ownership of './proc/sys/kernel/firmware_config/ignore_sysfs_fallback': Read-only file system
# chown: changing ownership of './proc/sys/kernel/firmware_config': Read-only file system
# chown: changing ownership of './proc/sys/kernel/ftrace_dump_on_oops': Read-only file system
# chown: changing ownership of './proc/sys/kernel/ftrace_enabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hardlockup_all_cpu_backtrace': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hardlockup_panic': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hostname': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hotplug': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hung_task_all_cpu_backtrace': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hung_task_check_count': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hung_task_check_interval_secs': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hung_task_panic': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hung_task_timeout_secs': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hung_task_warnings': Read-only file system
# chown: changing ownership of './proc/sys/kernel/hyperv_record_panic_msg': Read-only file system
# chown: changing ownership of './proc/sys/kernel/io_delay_type': Read-only file system
# chown: changing ownership of './proc/sys/kernel/io_uring_disabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/io_uring_group': Read-only file system
# chown: changing ownership of './proc/sys/kernel/kexec_load_disabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/kexec_load_limit_panic': Read-only file system
# chown: changing ownership of './proc/sys/kernel/kexec_load_limit_reboot': Read-only file system
# chown: changing ownership of './proc/sys/kernel/keys/gc_delay': Read-only file system
# chown: changing ownership of './proc/sys/kernel/keys/maxbytes': Read-only file system
# chown: changing ownership of './proc/sys/kernel/keys/maxkeys': Read-only file system
# chown: changing ownership of './proc/sys/kernel/keys/persistent_keyring_expiry': Read-only file system
# chown: changing ownership of './proc/sys/kernel/keys/root_maxbytes': Read-only file system
# chown: changing ownership of './proc/sys/kernel/keys/root_maxkeys': Read-only file system
# chown: changing ownership of './proc/sys/kernel/keys': Read-only file system
# chown: changing ownership of './proc/sys/kernel/kptr_restrict': Read-only file system
# chown: changing ownership of './proc/sys/kernel/latencytop': Read-only file system
# chown: changing ownership of './proc/sys/kernel/max_lock_depth': Read-only file system
# chown: changing ownership of './proc/sys/kernel/max_rcu_stall_to_panic': Read-only file system
# chown: changing ownership of './proc/sys/kernel/modprobe': Read-only file system
# chown: changing ownership of './proc/sys/kernel/modules_disabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/msg_next_id': Read-only file system
# chown: changing ownership of './proc/sys/kernel/msgmax': Read-only file system
# chown: changing ownership of './proc/sys/kernel/msgmnb': Read-only file system
# chown: changing ownership of './proc/sys/kernel/msgmni': Read-only file system
# chown: changing ownership of './proc/sys/kernel/ngroups_max': Read-only file system
# chown: changing ownership of './proc/sys/kernel/nmi_watchdog': Read-only file system
# chown: changing ownership of './proc/sys/kernel/ns_last_pid': Read-only file system
# chown: changing ownership of './proc/sys/kernel/numa_balancing': Read-only file system
# chown: changing ownership of './proc/sys/kernel/numa_balancing_promote_rate_limit_MBps': Read-only file system
# chown: changing ownership of './proc/sys/kernel/oops_all_cpu_backtrace': Read-only file system
# chown: changing ownership of './proc/sys/kernel/oops_limit': Read-only file system
# chown: changing ownership of './proc/sys/kernel/osrelease': Read-only file system
# chown: changing ownership of './proc/sys/kernel/ostype': Read-only file system
# chown: changing ownership of './proc/sys/kernel/overflowgid': Read-only file system
# chown: changing ownership of './proc/sys/kernel/overflowuid': Read-only file system
# chown: changing ownership of './proc/sys/kernel/panic': Read-only file system
# chown: changing ownership of './proc/sys/kernel/panic_on_io_nmi': Read-only file system
# chown: changing ownership of './proc/sys/kernel/panic_on_oops': Read-only file system
# chown: changing ownership of './proc/sys/kernel/panic_on_rcu_stall': Read-only file system
# chown: changing ownership of './proc/sys/kernel/panic_on_unrecovered_nmi': Read-only file system
# chown: changing ownership of './proc/sys/kernel/panic_on_warn': Read-only file system
# chown: changing ownership of './proc/sys/kernel/panic_print': Read-only file system
# chown: changing ownership of './proc/sys/kernel/perf_cpu_time_max_percent': Read-only file system
# chown: changing ownership of './proc/sys/kernel/perf_event_max_contexts_per_stack': Read-only file system
# chown: changing ownership of './proc/sys/kernel/perf_event_max_sample_rate': Read-only file system
# chown: changing ownership of './proc/sys/kernel/perf_event_max_stack': Read-only file system
# chown: changing ownership of './proc/sys/kernel/perf_event_mlock_kb': Read-only file system
# chown: changing ownership of './proc/sys/kernel/perf_event_paranoid': Read-only file system
# chown: changing ownership of './proc/sys/kernel/pid_max': Read-only file system
# chown: changing ownership of './proc/sys/kernel/poweroff_cmd': Read-only file system
# chown: changing ownership of './proc/sys/kernel/print-fatal-signals': Read-only file system
# chown: changing ownership of './proc/sys/kernel/printk': Read-only file system
# chown: changing ownership of './proc/sys/kernel/printk_delay': Read-only file system
# chown: changing ownership of './proc/sys/kernel/printk_devkmsg': Read-only file system
# chown: changing ownership of './proc/sys/kernel/printk_ratelimit': Read-only file system
# chown: changing ownership of './proc/sys/kernel/printk_ratelimit_burst': Read-only file system
# chown: changing ownership of './proc/sys/kernel/pty/max': Read-only file system
# chown: changing ownership of './proc/sys/kernel/pty/nr': Read-only file system
# chown: changing ownership of './proc/sys/kernel/pty/reserve': Read-only file system
# chown: changing ownership of './proc/sys/kernel/pty': Read-only file system
# chown: changing ownership of './proc/sys/kernel/random/boot_id': Read-only file system
# chown: changing ownership of './proc/sys/kernel/random/entropy_avail': Read-only file system
# chown: changing ownership of './proc/sys/kernel/random/poolsize': Read-only file system
# chown: changing ownership of './proc/sys/kernel/random/urandom_min_reseed_secs': Read-only file system
# chown: changing ownership of './proc/sys/kernel/random/uuid': Read-only file system
# chown: changing ownership of './proc/sys/kernel/random/write_wakeup_threshold': Read-only file system
# chown: changing ownership of './proc/sys/kernel/random': Read-only file system
# chown: changing ownership of './proc/sys/kernel/randomize_va_space': Read-only file system
# chown: changing ownership of './proc/sys/kernel/real-root-dev': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_autogroup_enabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_cfs_bandwidth_slice_us': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_deadline_period_max_us': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_deadline_period_min_us': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_energy_aware': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_rr_timeslice_ms': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_rt_period_us': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_rt_runtime_us': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_schedstats': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_util_clamp_max': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_util_clamp_min': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sched_util_clamp_min_rt_default': Read-only file system
# chown: changing ownership of './proc/sys/kernel/seccomp/actions_avail': Read-only file system
# chown: changing ownership of './proc/sys/kernel/seccomp/actions_logged': Read-only file system
# chown: changing ownership of './proc/sys/kernel/seccomp': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sem': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sem_next_id': Read-only file system
# chown: changing ownership of './proc/sys/kernel/shm_next_id': Read-only file system
# chown: changing ownership of './proc/sys/kernel/shm_rmid_forced': Read-only file system
# chown: changing ownership of './proc/sys/kernel/shmall': Read-only file system
# chown: changing ownership of './proc/sys/kernel/shmmax': Read-only file system
# chown: changing ownership of './proc/sys/kernel/shmmni': Read-only file system
# chown: changing ownership of './proc/sys/kernel/soft_watchdog': Read-only file system
# chown: changing ownership of './proc/sys/kernel/softlockup_all_cpu_backtrace': Read-only file system
# chown: changing ownership of './proc/sys/kernel/softlockup_panic': Read-only file system
# chown: changing ownership of './proc/sys/kernel/split_lock_mitigate': Read-only file system
# chown: changing ownership of './proc/sys/kernel/stack_tracer_enabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sysctl_writes_strict': Read-only file system
# chown: changing ownership of './proc/sys/kernel/sysrq': Read-only file system
# chown: changing ownership of './proc/sys/kernel/tainted': Read-only file system
# chown: changing ownership of './proc/sys/kernel/task_delayacct': Read-only file system
# chown: changing ownership of './proc/sys/kernel/threads-max': Read-only file system
# chown: changing ownership of './proc/sys/kernel/timer_migration': Read-only file system
# chown: changing ownership of './proc/sys/kernel/traceoff_on_warning': Read-only file system
# chown: changing ownership of './proc/sys/kernel/tracepoint_printk': Read-only file system
# chown: changing ownership of './proc/sys/kernel/unknown_nmi_panic': Read-only file system
# chown: changing ownership of './proc/sys/kernel/unprivileged_bpf_disabled': Read-only file system
# chown: changing ownership of './proc/sys/kernel/unprivileged_userns_apparmor_policy': Read-only file system
# chown: changing ownership of './proc/sys/kernel/unprivileged_userns_clone': Read-only file system
# chown: changing ownership of './proc/sys/kernel/user_events_max': Read-only file system
# chown: changing ownership of './proc/sys/kernel/usermodehelper/bset': Read-only file system
# chown: changing ownership of './proc/sys/kernel/usermodehelper/inheritable': Read-only file system
# chown: changing ownership of './proc/sys/kernel/usermodehelper': Read-only file system
# chown: changing ownership of './proc/sys/kernel/version': Read-only file system
# chown: changing ownership of './proc/sys/kernel/warn_limit': Read-only file system
# chown: changing ownership of './proc/sys/kernel/watchdog': Read-only file system
# chown: changing ownership of './proc/sys/kernel/watchdog_cpumask': Read-only file system
# chown: changing ownership of './proc/sys/kernel/watchdog_thresh': Read-only file system
# chown: changing ownership of './proc/sys/kernel/yama/ptrace_scope': Read-only file system
# chown: changing ownership of './proc/sys/kernel/yama': Read-only file system
# chown: changing ownership of './proc/sys/kernel': Read-only file system
# chown: changing ownership of './proc/sys/net/bridge/bridge-nf-call-arptables': Read-only file system
# chown: changing ownership of './proc/sys/net/bridge/bridge-nf-call-ip6tables': Read-only file system
# chown: changing ownership of './proc/sys/net/bridge/bridge-nf-call-iptables': Read-only file system
# chown: changing ownership of './proc/sys/net/bridge/bridge-nf-filter-pppoe-tagged': Read-only file system
# chown: changing ownership of './proc/sys/net/bridge/bridge-nf-filter-vlan-tagged': Read-only file system
# chown: changing ownership of './proc/sys/net/bridge/bridge-nf-pass-vlan-input-dev': Read-only file system
# chown: changing ownership of './proc/sys/net/bridge': Read-only file system
# chown: changing ownership of './proc/sys/net/core/bpf_jit_enable': Read-only file system
# chown: changing ownership of './proc/sys/net/core/bpf_jit_harden': Read-only file system
# chown: changing ownership of './proc/sys/net/core/bpf_jit_kallsyms': Read-only file system
# chown: changing ownership of './proc/sys/net/core/bpf_jit_limit': Read-only file system
# chown: changing ownership of './proc/sys/net/core/busy_poll': Read-only file system
# chown: changing ownership of './proc/sys/net/core/busy_read': Read-only file system
# chown: changing ownership of './proc/sys/net/core/default_qdisc': Read-only file system
# chown: changing ownership of './proc/sys/net/core/dev_weight': Read-only file system
# chown: changing ownership of './proc/sys/net/core/dev_weight_rx_bias': Read-only file system
# chown: changing ownership of './proc/sys/net/core/dev_weight_tx_bias': Read-only file system
# chown: changing ownership of './proc/sys/net/core/devconf_inherit_init_net': Read-only file system
# chown: changing ownership of './proc/sys/net/core/fb_tunnels_only_for_init_net': Read-only file system
# chown: changing ownership of './proc/sys/net/core/flow_limit_cpu_bitmap': Read-only file system
# chown: changing ownership of './proc/sys/net/core/flow_limit_table_len': Read-only file system
# chown: changing ownership of './proc/sys/net/core/gro_normal_batch': Read-only file system
# chown: changing ownership of './proc/sys/net/core/high_order_alloc_disable': Read-only file system
# chown: changing ownership of './proc/sys/net/core/max_skb_frags': Read-only file system
# chown: changing ownership of './proc/sys/net/core/mem_pcpu_rsv': Read-only file system
# chown: changing ownership of './proc/sys/net/core/message_burst': Read-only file system
# chown: changing ownership of './proc/sys/net/core/message_cost': Read-only file system
# chown: changing ownership of './proc/sys/net/core/netdev_budget': Read-only file system
# chown: changing ownership of './proc/sys/net/core/netdev_budget_usecs': Read-only file system
# chown: changing ownership of './proc/sys/net/core/netdev_max_backlog': Read-only file system
# chown: changing ownership of './proc/sys/net/core/netdev_rss_key': Read-only file system
# chown: changing ownership of './proc/sys/net/core/netdev_tstamp_prequeue': Read-only file system
# chown: changing ownership of './proc/sys/net/core/netdev_unregister_timeout_secs': Read-only file system
# chown: changing ownership of './proc/sys/net/core/optmem_max': Read-only file system
# chown: changing ownership of './proc/sys/net/core/rmem_default': Read-only file system
# chown: changing ownership of './proc/sys/net/core/rmem_max': Read-only file system
# chown: changing ownership of './proc/sys/net/core/rps_default_mask': Read-only file system
# chown: changing ownership of './proc/sys/net/core/rps_sock_flow_entries': Read-only file system
# chown: changing ownership of './proc/sys/net/core/skb_defer_max': Read-only file system
# chown: changing ownership of './proc/sys/net/core/somaxconn': Read-only file system
# chown: changing ownership of './proc/sys/net/core/tstamp_allow_data': Read-only file system
# chown: changing ownership of './proc/sys/net/core/txrehash': Read-only file system
# chown: changing ownership of './proc/sys/net/core/warnings': Read-only file system
# chown: changing ownership of './proc/sys/net/core/wmem_default': Read-only file system
# chown: changing ownership of './proc/sys/net/core/wmem_max': Read-only file system
# chown: changing ownership of './proc/sys/net/core/xfrm_acq_expires': Read-only file system
# chown: changing ownership of './proc/sys/net/core/xfrm_aevent_etime': Read-only file system
# chown: changing ownership of './proc/sys/net/core/xfrm_aevent_rseqth': Read-only file system
# chown: changing ownership of './proc/sys/net/core/xfrm_larval_drop': Read-only file system
# chown: changing ownership of './proc/sys/net/core': Read-only file system
# chown: changing ownership of './proc/sys/net/fan/vxlan': Read-only file system
# chown: changing ownership of './proc/sys/net/fan': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/cipso_cache_bucket_size': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/cipso_cache_enable': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/cipso_rbm_optfmt': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/cipso_rbm_strictvalid': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/accept_local': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/accept_redirects': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/accept_source_route': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/arp_accept': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/arp_announce': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/arp_evict_nocarrier': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/arp_filter': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/arp_ignore': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/arp_notify': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/bc_forwarding': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/bootp_relay': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/disable_policy': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/disable_xfrm': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/drop_gratuitous_arp': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/drop_unicast_in_l2_multicast': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/force_igmp_version': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/forwarding': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/igmpv2_unsolicited_report_interval': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/igmpv3_unsolicited_report_interval': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/ignore_routes_with_linkdown': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/log_martians': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/mc_forwarding': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/medium_id': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/promote_secondaries': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/proxy_arp': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/proxy_arp_pvlan': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/route_localnet': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/rp_filter': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/secure_redirects': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/send_redirects': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/shared_media': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/src_valid_mark': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all/tag': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/all': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/accept_local': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/accept_redirects': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/accept_source_route': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/arp_accept': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/arp_announce': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/arp_evict_nocarrier': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/arp_filter': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/arp_ignore': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/arp_notify': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/bc_forwarding': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/bootp_relay': Read-only file system
# chown: changing ownership of './proc/sys/net/ipv4/conf/default/disable_policy': Read-only file system
# ...
# chown: changing ownership of './sys/module/crc32_pclmul/sections/__patchable_function_entries': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.note.Linux': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.strtab': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/__mcount_loc': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.exit.text': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.exit.data': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.return_sites': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.gnu.linkonce.this_module': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.symtab': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.rodata': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.init.text': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.note.gnu.build-id': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.text': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.init.data': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.call_sites': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.data': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections/.rodata.str1.8': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul/sections': Read-only file system
# chown: changing ownership of './sys/module/crc32_pclmul': Read-only file system
# chown: changing ownership of './sys/module/printk/uevent': Read-only file system
# chown: changing ownership of './sys/module/printk/parameters/time': Read-only file system
# chown: changing ownership of './sys/module/printk/parameters/console_no_auto_verbose': Read-only file system
# chown: changing ownership of './sys/module/printk/parameters/console_suspend': Read-only file system
# chown: changing ownership of './sys/module/printk/parameters/always_kmsg_dump': Read-only file system
# chown: changing ownership of './sys/module/printk/parameters/ignore_loglevel': Read-only file system
# chown: changing ownership of './sys/module/printk/parameters': Read-only file system
# chown: changing ownership of './sys/module/printk': Read-only file system
# chown: changing ownership of './sys/module/vxlan/uevent': Read-only file system
# chown: changing ownership of './sys/module/vxlan/parameters/log_ecn_error': Read-only file system
# chown: changing ownership of './sys/module/vxlan/parameters/udp_port': Read-only file system
# chown: changing ownership of './sys/module/vxlan/parameters': Read-only file system
# chown: changing ownership of './sys/module/vxlan/version': Read-only file system
# chown: changing ownership of './sys/module/vxlan': Read-only file system
# chown: changing ownership of './sys/module/virtio_blk/uevent': Read-only file system
# chown: changing ownership of './sys/module/virtio_blk/parameters/num_request_queues': Read-only file system
# chown: changing ownership of './sys/module/virtio_blk/parameters/poll_queues': Read-only file system
# chown: changing ownership of './sys/module/virtio_blk/parameters/queue_depth': Read-only file system
# chown: changing ownership of './sys/module/virtio_blk/parameters': Read-only file system
# chown: changing ownership of './sys/module/virtio_blk': Read-only file system
# chown: changing ownership of './sys/module/watchdog/uevent': Read-only file system
# chown: changing ownership of './sys/module/watchdog/parameters/stop_on_reboot': Read-only file system
# chown: changing ownership of './sys/module/watchdog/parameters/handle_boot_enabled': Read-only file system
# chown: changing ownership of './sys/module/watchdog/parameters/open_timeout': Read-only file system
# chown: changing ownership of './sys/module/watchdog/parameters': Read-only file system
# chown: changing ownership of './sys/module/watchdog': Read-only file system
# chown: changing ownership of './sys/module/debug_core/uevent': Read-only file system
# chown: changing ownership of './sys/module/debug_core/parameters/kgdb_use_con': Read-only file system
# chown: changing ownership of './sys/module/debug_core/parameters/kgdbreboot': Read-only file system
# chown: changing ownership of './sys/module/debug_core/parameters': Read-only file system
# chown: changing ownership of './sys/module/debug_core': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/initsize': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/uevent': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/notes/.note.Linux': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/notes/.note.gnu.build-id': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/notes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/taint': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/allocated_vmalloc_bytes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/current_allocated_bytes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/allocated_kmem_cache_bytes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/max_cache_size_bytes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/max_age_seconds': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/retain_bytes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/peak_allocated_bytes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters/allocated_get_free_pages_bytes': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/parameters': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/srcversion': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/holders/dm_snapshot': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/holders': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/refcnt': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/coresize': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/initstate': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.altinstructions': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__patchable_function_entries': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__kcrctab_gpl': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__param': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__jump_table': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.note.Linux': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.strtab': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__mcount_loc': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.exit.text': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.exit.data': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.bss': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.return_sites': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.gnu.linkonce.this_module': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.symtab': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.rodata': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.init.text': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.note.gnu.build-id': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.text': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.init.data': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.call_sites': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.data': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.altinstr_replacement': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.smp_locks': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__bug_table': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.rodata.str1.1': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.text.unlikely': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.retpoline_sites': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__ksymtab_strings': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/__ksymtab_gpl': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.altinstr_aux': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections/.rodata.str1.8': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio/sections': Read-only file system
# chown: changing ownership of './sys/module/dm_bufio': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/initsize': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/uevent': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/notes/.note.Linux': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/notes/.note.gnu.build-id': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/notes': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/taint': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/srcversion': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/holders': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/refcnt': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/coresize': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/initstate': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/__patchable_function_entries': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.note.Linux': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.strtab': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/__mcount_loc': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.exit.text': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.rodata.cst16.gstar': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.exit.data': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.return_sites': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.gnu.linkonce.this_module': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.symtab': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.rodata': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.init.text': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.note.gnu.build-id': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.text': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.init.data': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.call_sites': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.data': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections/.rodata.str1.8': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni/sections': Read-only file system
# chown: changing ownership of './sys/module/polyval_clmulni': Read-only file system
# chown: changing ownership of './sys/module/virtio_net/uevent': Read-only file system
# chown: changing ownership of './sys/module/virtio_net/parameters/napi_weight': Read-only file system
# chown: changing ownership of './sys/module/virtio_net/parameters/csum': Read-only file system
# chown: changing ownership of './sys/module/virtio_net/parameters/napi_tx': Read-only file system
# chown: changing ownership of './sys/module/virtio_net/parameters/gso': Read-only file system
# chown: changing ownership of './sys/module/virtio_net/parameters': Read-only file system
# chown: changing ownership of './sys/module/virtio_net': Read-only file system
# chown: changing ownership of './sys/module/workqueue/uevent': Read-only file system
# chown: changing ownership of './sys/module/workqueue/parameters/cpu_intensive_thresh_us': Read-only file system
# chown: changing ownership of './sys/module/workqueue/parameters/default_affinity_scope': Read-only file system
# chown: changing ownership of './sys/module/workqueue/parameters/debug_force_rr_cpu': Read-only file system
# chown: changing ownership of './sys/module/workqueue/parameters/power_efficient': Read-only file system
# chown: changing ownership of './sys/module/workqueue/parameters': Read-only file system
# chown: changing ownership of './sys/module/workqueue': Read-only file system
# chown: changing ownership of './sys/module/tpm/uevent': Read-only file system
# chown: changing ownership of './sys/module/tpm/parameters/suspend_pcr': Read-only file system
# chown: changing ownership of './sys/module/tpm/parameters': Read-only file system
# chown: changing ownership of './sys/module/tpm/version': Read-only file system
# chown: changing ownership of './sys/module/tpm': Read-only file system
# chown: changing ownership of './sys/module/sr_mod/uevent': Read-only file system
# chown: changing ownership of './sys/module/sr_mod/parameters/xa_test': Read-only file system
# chown: changing ownership of './sys/module/sr_mod/parameters': Read-only file system
# chown: changing ownership of './sys/module/sr_mod': Read-only file system
# chown: changing ownership of './sys/module/drm/uevent': Read-only file system
# chown: changing ownership of './sys/module/drm/parameters/edid_firmware': Read-only file system
# chown: changing ownership of './sys/module/drm/parameters/edid_fixup': Read-only file system
# chown: changing ownership of './sys/module/drm/parameters/timestamp_precision_usec': Read-only file system
# chown: changing ownership of './sys/module/drm/parameters/debug': Read-only file system
# chown: changing ownership of './sys/module/drm/parameters/vblankoffdelay': Read-only file system
# chown: changing ownership of './sys/module/drm/parameters': Read-only file system
# chown: changing ownership of './sys/module/drm': Read-only file system
# chown: changing ownership of './sys/module': Read-only file system
# chown: changing ownership of './sys': Read-only file system

# %% [markdown]
# **Phd. Jose R. Zapata**
# - [https://joserzapata.github.io/](https://joserzapata.github.io/)
# - [https://www.linkedin.com/in/jose-ricardo-zapata-gonzalez/](https://www.linkedin.com/in/jose-ricardo-zapata-gonzalez/)

# %%
# Copie su código aca
# !pip3 install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in /home/vscode/.local/lib/python3.12/site-packages (21.0.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Esta celda ahora funcionará
df_texto.to_parquet("archivo.parquet", index=False)

# %%
# !ls -l
# Out:
# total 88
# -rw-r--r--    1 vscode vscode 6672 Oct 20 22:50 archivo.parquet
# lrwxrwxrwx    1 vscode root      7 Jun 30 00:00 bin -> usr/bin
# drwxr-xr-x    1 vscode root   4096 May  9 14:50 boot
# drwxr-xr-x    5 vscode root    340 Oct 20 21:28 dev
# drwxr-xr-x    1 vscode root   4096 Oct 18 19:34 etc
# drwxr-xr-x    1 vscode root   4096 Jul 10 11:40 home
# lrwxrwxrwx    1 vscode root      7 Jun 30 00:00 lib -> usr/lib
# lrwxrwxrwx    1 vscode root      9 Jun 30 00:00 lib64 -> usr/lib64
# drwxr-xr-x    1 vscode root   4096 Jun 30 00:00 media
# drwxr-xr-x    1 vscode root   4096 Jun 30 00:00 mnt
# drwxr-xr-x    1 vscode root   4096 Jun 30 00:00 opt
# dr-xr-xr-x  239 vscode root      0 Oct 20 21:28 proc
# drwx------    1 vscode root   4096 Oct 18 19:35 root
# drwxr-xr-x    1 vscode root   4096 Jul  1 03:19 run
# lrwxrwxrwx    1 vscode root      8 Jun 30 00:00 sbin -> usr/sbin
# drwxr-xr-x    1 vscode root   4096 Jun 30 00:00 srv
# dr-xr-xr-x   12 root   root      0 Oct 20 21:24 sys
# drwxr-xrwt+   6 vscode root   4096 Oct 20 22:44 tmp
# drwxr-xr-x    1 vscode root   4096 Jun 30 00:00 usr
# drwxr-xr-x    1 vscode root   4096 Oct 18 19:34 var
# drwxr-xr-x    5 vscode root   4096 Oct 20 21:27 vscode
# drwxr-xrwx+   4 vscode root   4096 Oct 18 19:33 workspaces

# %%
import pandas as pd

df_leido = pd.read_parquet("archivo.parquet")
print(df_leido.head())
# Out:
#                                                texto  \
# 0    ¡Hola Mundo!!!  Esto es   un EJEMPLO: visita...
# 1   Pandas > numpy? 🤔  Email: persona@example.com
# 2  Me gusta el café colombiano; es buenísimo!!! #...
# 3  Oferta!!! 3x2 en jabón líquido 500ml - CÓDIGO:...
# 4        TABLAS\t, \n espacios   y saltos de líne...
#
#                                            texto_min  \
# 0    ¡hola mundo!!!  esto es   un ejemplo: visita...
# 1   pandas > numpy? 🤔  email: persona@example.com
# 2  me gusta el café colombiano; es buenísimo!!! #...
# 3  oferta!!! 3x2 en jabón líquido 500ml - código:...
# 4        tablas\t, \n espacios   y saltos de líne...
#
#                                       texto_espacios  \
# 0  ¡hola mundo!!!  esto es   un ejemplo: visita h...
# 1      pandas > numpy? 🤔  email: persona@example.com
# 2  me gusta el café colombiano; es buenísimo!!! #...
# 3  oferta!!! 3x2 en jabón líquido 500ml - código:...
# 4         tablas\t, \n espacios   y saltos de línea.
#
#                                      texto_sin_punct  \
# 0  hola mundo  esto es   un ejemplo visita httpsm...
# 1            pandas  numpy   email personaexamplecom
# 2  me gusta el café colombiano es buenísimo café ...
# 3     oferta 3x2 en jabón líquido 500ml  código a123
# 4           tablas\t \n espacios   y saltos de línea
#
#                                    texto_sin_acentos
# 0  hola mundo  esto es   un ejemplo visita httpsm...
# 1            pandas  numpy   email personaexamplecom
# 2  me gusta el cafe colombiano es buenisimo cafe ...
# 3     oferta 3x2 en jabon liquido 500ml  codigo a123
# 4           tablas\t \n espacios   y saltos de linea
